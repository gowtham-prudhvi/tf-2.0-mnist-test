# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham-prudhvi/tf-2.0-mnist-test/blob/master/TF2_0_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras.models as models
import tensorflow.keras.layers as layers
print(tf.__version__)
# Out:
# 2.0.0

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()
print(len(x_train),len(x_test))

x_train = x_train/255.0
x_test = x_test/255.0
# Out:
# 60000 10000

# %%
model = models.Sequential([
  layers.Flatten(input_shape=(28,28)),
  layers.Dense(128,activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x=x_train,y=y_train,epochs=5)

model.evaluate(x=x_test,y=y_test)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.4162 - accuracy: 0.9009
# Epoch 2/5
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.3802 - accuracy: 0.9043
# Epoch 3/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.3612 - accuracy: 0.9102
# Epoch 4/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.3456 - accuracy: 0.9143
# Epoch 5/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.3364 - accuracy: 0.9166
# ...
